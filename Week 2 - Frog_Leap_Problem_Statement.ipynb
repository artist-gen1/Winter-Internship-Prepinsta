# %%
positions = ['G', 'G', 'G', '-', 'B', 'B', 'B']
print("[ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]")
print(positions)

i = 0

while i == 0:
    pos = input("Press q to quit else \nEnter position of piece:")
    if pos == 'q':
        print("You Lose")
    else:
        selected_pos = int(pos)
        print(selected_pos)

    if selected_pos < 0 or 6 < selected_pos:
        print("Invalid Move")
    
    if positions[selected_pos] == '-':
        print("Invalid Move")
    
    pos2 = 0

    if positions[selected_pos] == 'G':
        if positions[selected_pos + 1] == '-':
            pos2 = selected_pos + 1
            positions[selected_pos] = '-'
            positions[pos2] = 'G'
        elif positions[selected_pos + 2] == '-':
            pos2 = selected_pos + 2
            positions[selected_pos] = '-'
            positions[pos2] = 'G'
        else:
            print("Invalid Move")

    if positions[selected_pos] == 'B':
        if positions[selected_pos - 1] == '-':
            pos2 = selected_pos - 1
            positions[selected_pos] = '-'
            positions[pos2] = 'B'
        elif positions[selected_pos - 2] == '-':
            pos2 = selected_pos - 2
            positions[selected_pos] = '-'
            positions[pos2] = 'B'
        else:
            print("Invalid Move")
       
    #  code for Oops, they are stuck!  
    # if positions[]
        
    if positions == ['B', 'B', 'B', '-', 'G', 'G', 'G']:
        print("You Win")
        break

    print("[ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]")
    print(positions)
# Out:
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'G', '-', 'B', 'B', 'B']
# 4
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', 'G', 'B', '-', 'B', 'B']
# 2
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'G', '-', 'B', 'G', 'B', 'B']
# 1
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', '-', 'G', 'B', 'G', 'B', 'B']
# 3
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'B', 'G', '-', 'G', 'B', 'B']
# 5
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'B', 'G', 'B', 'G', '-', 'B']
# 6
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'B', 'G', 'B', 'G', 'B', '-']
# 4
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'B', 'G', 'B', '-', 'B', 'G']
# 2
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['G', 'B', '-', 'B', 'G', 'B', 'G']
# 0
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['-', 'B', 'G', 'B', 'G', 'B', 'G']
# 1
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['B', '-', 'G', 'B', 'G', 'B', 'G']
# 3
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ['B', 'B', 'G', '-', 'G', 'B', 'G']
# 5
# [ 0 ,  1 ,  2 ,  3 ,  4 ,  5 ,  6 ]
# ...
